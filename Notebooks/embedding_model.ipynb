# %%
# Ensure working directory to project code folder
import os

os.chdir("/ceph/behrens/peter_doohan/goalNav_mFC/experiment/code")
print("Current Working Directory: ", os.getcwd())

from importlib import reload
# Out:
# Current Working Directory:  /ceph/behrens/peter_doohan/goalNav_mFC/experiment/code

# %%
from matplotlib import pyplot as plt

plt.rcParams.update(
    {
        "font.size": 12,
        "axes.titlesize": 16,
        "axes.labelsize": 14,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 8,
        "figure.titlesize": 18,
        "pdf.fonttype": 42,
    }
)
from matplotlib.gridspec import GridSpec
from importlib import reload

# %%
from GridMaze.analysis.core import get_clusters as gc
from GridMaze.analysis.cluster_tuning import summary

# %%
Cluster = gc.get_cluster("m6.2022-07-05.maze_cluster6")
fig = summary.plot_tuning_summary_concise(Cluster)

# %%
from GridMaze.analysis.embedding_model import input_feature_comparisons as ifc

# %%
reload(ifc)
fig, ax = plt.subplots(1, 1, figsize=(3, 4), clear=True)
ifc.plot_state_action_interaction_results(ax=ax)
fig.savefig("../results/embedding_model/figures/place_direction_interaction.pdf")
# Out:
# /ceph/behrens/peter_doohan/goalNav_mFC/experiment/code/GridMaze/analysis/embedding_model/input_feature_comparisons.py:434: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xlabel("")

# %%
reload(ifc)
fig, ax = plt.subplots(1, 1, figsize=(3, 4), clear=True)
ifc.plot_state_action_distance_CPD(ax=ax)
fig.savefig("../results/embedding_model/figures/place_direction_distance_CPD.pdf")
# Out:
# m2_maze_1_state-action-distance_no-embedding not found, probably still running. Returning None.
